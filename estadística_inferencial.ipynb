# %% [markdown]
# # Estadística Inferencial

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats
from scipy.stats import shapiro, kstest, poisson, chisquare, expon 
# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("files/world_data_full_apply_nulos.csv", index_col = 0)

# %%
data.head(5)
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
# 2        150.006  151.36         2.0           DZD            3.02
# 3        469.000     NaN         NaN           EUR            1.27
# 4         34.693  261.73        17.1           AOA            5.52
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
# 2            0.8            0.28  1.699882e+11
# 3           34.0            1.51  3.154058e+09
# 4           46.3            0.97  9.463542e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# 1                               107.0                                 55.0
# 2                               109.9                                 51.4
# 3                               106.4                                  NaN
# 4                               113.5                                  9.3
#
#    infant_mortality      largest_city  life_expectancy  \
# 0              47.9             Kabul             64.5
# 1               7.8            Tirana             78.5
# 2              20.1           Algiers             76.7
# 3               2.7  Andorra la Vella              NaN
# 4              51.6            Luanda             60.8
#
#    maternal_mortality_ratio  minimum_wage official_language  \
# 0                     638.0          0.43            Pashto
# 1                      15.0          1.12          Albanian
# 2                     112.0          0.95            Arabic
# 3                       NaN          6.63           Catalan
# 4                     241.0          0.71        Portuguese
#
#    out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 0                              78.4                     0.28         NaN
# 1                              56.9                     1.20         NaN
# 2                              28.1                     1.72         NaN
# 3                              36.4                     3.33      77.142
# 4                              33.4                     0.21         NaN
#
#    population_labor_force_participation  tax_revenue  total_tax_rate  \
# 0                                  48.9          9.3            71.4
# 1                                  55.7         18.6            36.6
# 2                                  41.2         37.2            66.1
# 3                                   NaN          NaN             NaN
# 4                                  77.5          9.2            49.1
#
#    unemployment_rate  urban_population   latitude  longitude continent
# 0              11.12               NaN  33.939110  67.709953      Asia
# 1              12.33               NaN  41.153332  20.168331    Europe
# 2              11.70               NaN  28.033886   1.659626    Africa
# 3                NaN            67.873  42.506285   1.521801    Europe
# 4               6.89               NaN -11.202692  17.873887    Africa

# %% [markdown]
# ### 1.Igual que en los ejercicios de la clase invertida, evalúa si las siguientes afirmaciones corresponden a una distribución exponencial o poisson.

# %% [markdown]
# ¿El tiempo que transcurre entre la llegada de autobuses a una parada sigue una distribución exponencial o de Poisson?

# %% [markdown]
# Sigue una distribución exponencial porque mide el tiempo que transcurre entre eventos.

# %% [markdown]
# ¿El número de errores en un artículo de noticias sigue una distribución exponencial o de Poisson?

# %% [markdown]
# Poisson porque se cuantifica el número de eventos.

# %% [markdown]
# ¿El tiempo que transcurre entre la llegada de solicitudes de servicio en un restaurante sigue una distribución exponencial o de Poisson?

# %% [markdown]
# Sigue una distribución exponencial porque mide el tiempo que transcurre entre eventos porque tiene una duración positiva y los eventos sin independientes.

# %% [markdown]
# ¿El número de accidentes de tráfico en una hora en una ciudad sigue una distribución exponencial o de Poisson?

# %% [markdown]
# Poisson porque se cuantifica el número de eventos.

# %% [markdown]
# ¿El tiempo entre llegadas de llamadas telefónicas a una central de emergencias sigue una distribución exponencial o de Poisson?

# %% [markdown]
# Sigue una distribución exponencial porque mide el tiempo que transcurre entre eventos.

# %% [markdown]
# ¿El número de clientes que ingresan a una tienda en una hora sigue una distribución exponencial o de Poisson?

# %% [markdown]
# Poisson porque se cuantifica el número de eventos.

# %% [markdown]
# ¿El tiempo entre llegadas de correos electrónicos en una bandeja de entrada sigue una distribución exponencial o de Poisson?

# %% [markdown]
# Sigue una distribución exponencial porque mide el tiempo que transcurre entre eventos.

# %% [markdown]
# ¿El número de defectos en una línea de producción por día sigue una distribución exponencial o de Poisson?

# %% [markdown]
# Poisson porque se cuantifica el número de eventos.

# %% [markdown]
# ¿El tiempo que transcurre entre la llegada de taxis en una parada sigue una distribución exponencial o de Poisson?

# %% [markdown]
# Sigue una distribución exponencial porque mide el tiempo que transcurre entre eventos.

# %% [markdown]
# ¿El número de errores de ortografía en un libro de texto sigue una distribución exponencial o de Poisson?

# %% [markdown]
# Poisson porque se cuantifica el número de eventos.

# %% [markdown]
# ### 2.Ejercicios intervalo de confianza. Al igual que en el caso del ejercicio de la clase invertida, piensa un motivo por el que sería interesante calcular estos intervalos de confianza para la extracción de insights.

# %%
data.head(5)
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
# 2        150.006  151.36         2.0           DZD            3.02
# 3        469.000     NaN         NaN           EUR            1.27
# 4         34.693  261.73        17.1           AOA            5.52
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
# 2            0.8            0.28  1.699882e+11
# 3           34.0            1.51  3.154058e+09
# 4           46.3            0.97  9.463542e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# 1                               107.0                                 55.0
# 2                               109.9                                 51.4
# 3                               106.4                                  NaN
# 4                               113.5                                  9.3
#
#    infant_mortality      largest_city  life_expectancy  \
# 0              47.9             Kabul             64.5
# 1               7.8            Tirana             78.5
# 2              20.1           Algiers             76.7
# 3               2.7  Andorra la Vella              NaN
# 4              51.6            Luanda             60.8
#
#    maternal_mortality_ratio  minimum_wage official_language  \
# 0                     638.0          0.43            Pashto
# 1                      15.0          1.12          Albanian
# 2                     112.0          0.95            Arabic
# 3                       NaN          6.63           Catalan
# 4                     241.0          0.71        Portuguese
#
#    out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 0                              78.4                     0.28         NaN
# 1                              56.9                     1.20         NaN
# 2                              28.1                     1.72         NaN
# 3                              36.4                     3.33      77.142
# 4                              33.4                     0.21         NaN
#
#    population_labor_force_participation  tax_revenue  total_tax_rate  \
# 0                                  48.9          9.3            71.4
# 1                                  55.7         18.6            36.6
# 2                                  41.2         37.2            66.1
# 3                                   NaN          NaN             NaN
# 4                                  77.5          9.2            49.1
#
#    unemployment_rate  urban_population   latitude  longitude continent
# 0              11.12               NaN  33.939110  67.709953      Asia
# 1              12.33               NaN  41.153332  20.168331    Europe
# 2              11.70               NaN  28.033886   1.659626    Africa
# 3                NaN            67.873  42.506285   1.521801    Europe
# 4               6.89               NaN -11.202692  17.873887    Africa

# %% [markdown]
# 1. Calcular la media de la columna :  media_duracion = df["duration"].mean()
# 	2. Calcular el error estándar: error_duracion = stats.sem(df["duration"])
# 	3. Definir el nivel de confianza nivel_confianza_duracion = 0.95
# 	4. Calcular los grados de libertad: grados_libertad_duracion = len(df["duration"]) - 1
# 	5. Calcular el valor crítico de la muestra: stats.t.ppf((1 + nivel_confianza_duracion) / 2, df=grados_libertad_duracion)
# 	6. Calcular el intervalo de confianza:
# 	limite_inferior_duracion = media_duracion - valor_critico_duracion * error_duracion
# limite_superior_duracion = media_duracion + valor_critico_duracion * error_duracion

# %% [markdown]
# **Intervalo de Confianza para la Esperanza de Vida**
#
# Contexto: Trabajas en una organización de salud global y deseas estimar el intervalo de confianza al 95% para la esperanza de vida promedio de cada continente.
#
# Nota: Cuidado porque puede que os salgan algunos nulos, genera un código para que no salgan nulos en los intervalos de confianza.

# %%
# Se sustiyuen los nulos por la mediana
data["life_expectancy"]= data["life_expectancy"].fillna(data["life_expectancy"].median())

# %%
(data["life_expectancy"].isna().sum()/data.shape[0] )*100
# Out:
# 0.0

# %%
media_lifexp = data["life_expectancy"].mean()

# %%
error_lifexp = stats.sem(data["life_expectancy"])

# %%
nivel_lifexp = 0.95

# %%
grados_lifexp = len(data["life_expectancy"]) - 1

# %%
valor_critico_lifexp = stats.t.ppf((1 + nivel_lifexp ) / 2, df=grados_lifexp )

# %%
limite_inferior_lifexp = media_lifexp - valor_critico_lifexp * error_lifexp
limite_superior_lifexp = media_lifexp + valor_critico_lifexp * error_lifexp

# %%
print(f"Nuestro intervalo de confianza para un nivel del 95% está entre: {limite_inferior_lifexp} y {limite_superior_lifexp}")
# Out:
# Nuestro intervalo de confianza para un nivel del 95% está entre: 71.28216591512167 y 73.35270587975008

# %% [markdown]
# **Intervalo de Confianza para el PIB**
#
# Contexto: Eres una economista y quieres calcular el intervalo de confianza al 90% para el Producto Interno Bruto (PIB) de los continentes.

# %%
data.head(5)
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
# 2        150.006  151.36         2.0           DZD            3.02
# 3        469.000     NaN         NaN           EUR            1.27
# 4         34.693  261.73        17.1           AOA            5.52
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
# 2            0.8            0.28  1.699882e+11
# 3           34.0            1.51  3.154058e+09
# 4           46.3            0.97  9.463542e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# 1                               107.0                                 55.0
# 2                               109.9                                 51.4
# 3                               106.4                                  NaN
# 4                               113.5                                  9.3
#
#    infant_mortality      largest_city  life_expectancy  \
# 0              47.9             Kabul             64.5
# 1               7.8            Tirana             78.5
# 2              20.1           Algiers             76.7
# 3               2.7  Andorra la Vella             73.2
# 4              51.6            Luanda             60.8
#
#    maternal_mortality_ratio  minimum_wage official_language  \
# 0                     638.0          0.43            Pashto
# 1                      15.0          1.12          Albanian
# 2                     112.0          0.95            Arabic
# 3                       NaN          6.63           Catalan
# 4                     241.0          0.71        Portuguese
#
#    out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 0                              78.4                     0.28         NaN
# 1                              56.9                     1.20         NaN
# 2                              28.1                     1.72         NaN
# 3                              36.4                     3.33      77.142
# 4                              33.4                     0.21         NaN
#
#    population_labor_force_participation  tax_revenue  total_tax_rate  \
# 0                                  48.9          9.3            71.4
# 1                                  55.7         18.6            36.6
# 2                                  41.2         37.2            66.1
# 3                                   NaN          NaN             NaN
# 4                                  77.5          9.2            49.1
#
#    unemployment_rate  urban_population   latitude  longitude continent
# 0              11.12               NaN  33.939110  67.709953      Asia
# 1              12.33               NaN  41.153332  20.168331    Europe
# 2              11.70               NaN  28.033886   1.659626    Africa
# 3                NaN            67.873  42.506285   1.521801    Europe
# 4               6.89               NaN -11.202692  17.873887    Africa

# %%
data["gdp"].isna().sum()
# Out:
# 2

# %%
data["gdp"]= data["gdp"].fillna(data["gdp"].median())

# %%
(data["gdp"].isna().sum()/data.shape[0] )*100
# Out:
# 0.0

# %%
media_pib = data["gdp"].mean()
error_pib = stats.sem(data["gdp"])
nivel_pib = 0.90
grados_pib = len(data["gdp"]) - 1
valor_critico_pib = stats.t.ppf((1 + nivel_pib ) / 2, df=grados_pib )
limite_inferior_pib = media_pib - valor_critico_pib * error_pib
limite_superior_pib = media_pib + valor_critico_pib * error_pib

# %%
print(f"Nuestro intervalo de confianza para un nivel del 90% está entre: {limite_inferior_pib} y {limite_superior_pib}")
# Out:
# Nuestro intervalo de confianza para un nivel del 90% está entre: 216938197161.98798 y 728568299546.5557

# %% [markdown]
# **Intervalo de Confianza para la Tasa de Natalidad**
#
# Contexto: Trabajas en una agencia gubernamental que se ocupa de cuestiones demográficas y deseas determinar el intervalo de confianza al 99% para la tasa de natalidad promedio en Asia.

# %%
data["birth_rate"].isna().sum()
# Out:
# 6

# %%
data["birth_rate"]= data["birth_rate"].fillna(data["birth_rate"].median())

# %%
(data["birth_rate"].isna().sum()/data.shape[0] )*100
# Out:
# 0.0

# %%
media_birthrate = data["birth_rate"].mean()
error_birthrate = stats.sem(data["birth_rate"])
nivel_birthrate = 0.99
grados_birthrate = len(data["birth_rate"]) - 1
valor_critico_birthrate = stats.t.ppf((1 + nivel_birthrate ) / 2, df=grados_birthrate )
limite_inferior_birthrate = media_birthrate - valor_critico_birthrate * error_birthrate
limite_superior_birthrate = media_birthrate + valor_critico_birthrate * error_birthrate
print(f"Nuestro intervalo de confianza para un nivel del 99% está entre: {limite_inferior_birthrate} y {limite_superior_birthrate}")
# Out:
# Nuestro intervalo de confianza para un nivel del 99% está entre: 18.319890638106166 y 21.970673464457924

# %% [markdown]
# **Intervalo de Confianza para la Tasa de Desempleo**
#
# Contexto: Eres un analista de políticas públicas y deseas calcular el intervalo de confianza al 95% para la tasa de desempleo promedio en los países de Oceanía.

# %%
data["continent"].isna().sum()
# Out:
# 1

# %%
data['continent'].index[data['continent'].isnull()]
# Out:
# Int64Index([150], dtype='int64')

# %%
data.iloc[150, :]
# Out:
# country                                 S�����������
# density                                        228.0
# abbreviation                                      ST
# agricultural_land                               50.7
# land_area                                      964.0
# armed_forces_size                                1.0
# birth_rate                                     31.54
# calling_code                                   239.0
# capital/major_city                             S����
# co2-emissions                                  121.0
# cpi                                           185.09
# cpi_change                                       7.9
# currency-code                                    STN
# fertility_rate                                  4.32
# forested_area                                   55.8
# gasoline_price                                   NaN
# gdp                                      429016605.0
# gross_primary_education_enrollment             106.8
# gross_tertiary_education_enrollment             13.4
# infant_mortality                                24.4
# largest_city                                   S����
# life_expectancy                                 70.2
# maternal_mortality_ratio                       130.0
# minimum_wage                                     NaN
# official_language                                NaN
# out_of_pocket_health_expenditure                11.7
# physicians_per_thousand                         0.05
# population                                   215.056
# population_labor_force_participation            57.8
# tax_revenue                                     14.6
# total_tax_rate                                  37.0
# unemployment_rate                              13.37
# urban_population                             158.277
# latitude                                         NaN
# longitude                                        NaN
# continent                                        NaN
# Name: 150, dtype: object

# %%
data["country"][150]= 'Sao Tome and Principe'
data["capital/major_city"][150]= 'Sao Tome'
data["largest_city"][150]= 'Sao Tome'
data["continent"][150] = "Africa"

# %%
data_oceania = data[data["continent"] == "Oceania"]

# %%
data_oceania.head(5)
# Out:
#                             country  density abbreviation  agricultural_land  \
# 8                         Australia      3.0           AU               48.2
# 58                             Fiji     49.0           FJ               23.3
# 89                         Kiribati    147.0           KI               42.0
# 107                Marshall Islands    329.0           MH               63.9
# 111  Federated States of Micronesia    784.0           FM               31.4
#
#      land_area  armed_forces_size  birth_rate  calling_code  \
# 8          NaN               58.0       12.60          61.0
# 58      18.274                4.0       21.28         679.0
# 89     811.000                NaN       27.89         686.0
# 107    181.000                NaN       29.03         692.0
# 111    702.000                NaN       22.82         691.0
#
#     capital/major_city  co2-emissions     cpi  cpi_change currency-code  \
# 8             Canberra        375.908  119.80         1.6           AUD
# 58                Suva          2.046  132.30         1.8           FJD
# 89        South Tarawa         66.000   99.55         0.6           AUD
# 107             Majuro        143.000     NaN         NaN           USD
# 111            Palikir        143.000  112.10         0.5           USD
#
#      fertility_rate  forested_area  gasoline_price           gdp  \
# 8              1.74           16.3            0.93  1.392681e+12
# 58             2.77           55.9            0.82  5.535549e+09
# 89             3.57           15.0             NaN  1.946472e+08
# 107            4.05           70.2            1.44  2.212780e+08
# 111            3.05           91.9             NaN  4.019323e+08
#
#      gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 8                                 100.3                                113.1
# 58                                106.4                                 16.1
# 89                                101.3                                  NaN
# 107                                84.7                                 23.7
# 111                                97.2                                 14.1
#
#      infant_mortality  largest_city  life_expectancy  \
# 8                 3.1        Sydney             82.7
# 58               21.6          Suva             67.3
# 89               41.2  South Tarawa             68.1
# 107              27.4        Majuro             65.2
# 111              25.6       Palikir             67.8
#
#      maternal_mortality_ratio  minimum_wage official_language  \
# 8                         6.0         13.59               NaN
# 58                       34.0          1.28        Fiji Hindi
# 89                       92.0           NaN           English
# 107                       NaN          2.00       Marshallese
# 111                      88.0           NaN           English
#
#      out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 8                                19.6                     3.68         NaN
# 58                               21.4                     0.84     889.953
# 89                                0.2                     0.20     117.606
# 107                              10.0                     0.42      58.791
# 111                               2.5                     0.18     113.815
#
#      population_labor_force_participation  tax_revenue  total_tax_rate  \
# 8                                    65.5         23.0            47.4
# 58                                   57.6         24.2            32.1
# 89                                    NaN         22.0            32.7
# 107                                   NaN         17.8            65.9
# 111                                   NaN         25.2            60.5
#
#      unemployment_rate  urban_population   latitude   longitude continent
# 8                 5.27               NaN -25.274398  133.775136   Oceania
# 58                4.10           505.048 -17.713371  178.065032   Oceania
# 89                 NaN            64.489   1.836898 -157.376832   Oceania
# 107                NaN            45.514   7.131474  171.184478   Oceania
# 111                NaN            25.963   7.425554  150.550812   Oceania

# %%
data_desempleo = data.groupby("continent" == "Oceania")["unemployment_rate", "continent"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/z0/ptwngvg97wndky1th_f_rz8r0000gp/T/ipykernel_37555/3677175101.py in <module>
# ----> 1 data_desempleo = data.groupby("continent" == "Oceania")["unemployment_rate", "continent"]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# --> 889             grouper, exclusions, obj = get_grouper(
#     890                 obj,
#     891                 keys,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     860                 in_axis, level, gpr = False, gpr, None
#     861             else:
# --> 862                 raise KeyError(gpr)
#     863         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     864             # Add key to exclusions
#
# KeyError: False

# %%
data_desempleo.head(5)
# Out:
# 0      11.12
# 1      12.33
# 2      11.70
# 3        NaN
# 4       6.89
# 5        NaN
# 6       9.79
# 7      16.99
# 8       5.27
# 9       4.67
# 10      5.51
# 11     10.36
# 12      0.71
# 13      4.19
# 14     10.33
# 15      4.59
# 16      5.59
# 17      6.41
# 18      2.23
# 20      3.50
# 22     18.19
# 23     12.08
# 26      6.26
# 32      5.56
# 35      7.09
# 37      9.71
# 40     11.85
# 58      4.10
# 89       NaN
# 107      NaN
# 111      NaN
# 186    14.70
# Name: unemployment_rate, dtype: float64

# %%
(data_desempleo.isna().sum()/data_desempleo.shape[0] )*100
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/z0/ptwngvg97wndky1th_f_rz8r0000gp/T/ipykernel_37555/2920188177.py in <module>
# ----> 1 (data_desempleo.isna().sum()/data_desempleo.shape[0] )*100
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'isna'

# %%
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
# hemos dicho que para las tres columnas restantes aplicaremos los dos métodos para luego compararlos, empezaremos por el IterativeImputer
# instanciamos las clases
imputer_iterative = IterativeImputer(max_iter = 20, random_state = 42)
# ajustamos y tranformamos los datos
imputer_iterative_imputado = imputer_iterative.fit_transform(data["unemployment_rate"])
# comprobamos que es lo que nos devuelve, que en este caso es un array también
imputer_iterative_imputado
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/z0/ptwngvg97wndky1th_f_rz8r0000gp/T/ipykernel_27267/2687059617.py in <module>
#       3 imputer_iterative = IterativeImputer(max_iter = 20, random_state = 42)
#       4 # ajustamos y tranformamos los datos
# ----> 5 imputer_iterative_imputado = imputer_iterative.fit_transform(data["unemployment_rate"])
#       6 # comprobamos que es lo que nos devuelve, que en este caso es un array también
#       7 imputer_iterative_imputado
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py in fit_transform(self, X, y)
#     605
#     606         X, Xt, mask_missing_values, complete_mask = (
# --> 607             self._initial_imputation(X, in_fit=True))
#     608
#     609         super()._fit_indicator(complete_mask)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py in _initial_imputation(self, X, in_fit)
#     510             force_all_finite = True
#     511
# --> 512         X = self._validate_data(X, dtype=FLOAT_DTYPES, order="F", reset=in_fit,
#     513                                 force_all_finite=force_all_finite)
#     514         _check_inputs_dtype(X, self.missing_values)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     692             # If input is 1D raise error
#     693             if array.ndim == 1:
# --> 694                 raise ValueError(
#     695                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     696                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[11.12 12.33 11.7    nan  6.89   nan  9.79 16.99  5.27  4.67  5.51 10.36
#   0.71  4.19 10.33  4.59  5.59  6.41  2.23  2.34  3.5  18.42 18.19 12.08
#   9.12  4.34  6.26  1.43  3.32 12.25  0.68  3.38  5.56  3.68  1.89  7.09
#   4.32  9.71  4.34  9.47 11.85  6.93  1.64  7.27  1.93  4.24  4.91 10.3
#    nan  5.84  3.97 10.76  4.11  6.43  5.14  5.11   nan  2.08  4.1   6.59
#   8.43 20.    9.06 14.4   3.04  4.33 17.24   nan  2.46  4.3   2.47 11.85
#  13.78   nan  5.39  3.4   2.84  5.36  4.69 11.38 12.82  4.93  3.86  9.89
#   8.    2.29 14.72  4.59  2.64   nan  2.18  6.33  0.63  6.52  6.23 23.41
#   2.81 18.56   nan  6.35  5.36  1.76  5.65  3.32  6.14  7.22  3.47   nan
#   9.55  6.67  3.42   nan  5.47   nan  6.01 14.88  9.02  3.24  1.58 20.27
#    nan  1.41  3.2   4.07  6.84  0.47  8.1   2.74   nan  3.35  2.67  4.45
#    nan   nan  3.9   2.46  4.81  3.31  2.15  3.47  6.33  0.09  3.98  4.59
#   1.03   nan 20.71 18.88  8.36   nan 13.37  5.93  6.6  12.69   nan  4.43
#   4.11  5.56  4.2   0.58 11.35 28.18  4.15 12.24 13.96  4.2  16.53  7.33
#   6.48  4.58  8.37 11.02  1.98  0.75  4.55  2.04  1.12  2.69 16.02 13.49
#   3.91   nan  1.84  8.88  2.35  3.85 14.7   8.73  5.92  4.39  8.8   2.01
#  12.91 11.43  4.95].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
media_unemployment_rate = data["unemployment_rate"].mean()
error_unemployment_rate = stats.sem(data["unemployment_rate"])
nivel_unemployment_rate = 0.95
grados_unemployment_rate = len(data["unemployment_rate"]) - 1
valor_critico_unemployment_rate = stats.t.ppf((1 + nivel_unemployment_rate ) / 2, df=grados_unemployment_rate )
limite_inferior_unemployment_rate = media_unemployment_rate - valor_critico_unemployment_rate * error_unemployment_rate
limite_superior_unemployment_rate = media_unemployment_rate + valor_critico_unemployment_rate * error_unemployment_rate
print(f"Nuestro intervalo de confianza para un nivel del 95% está entre: {limite_inferior_unemployment_rate} y {limite_superior_unemployment_rate}")

# %% [markdown]
# **Intervalo de Confianza para la Tasa de Impuestos**
#
# Contexto: Trabajas en un ministerio de finanzas y deseas estimar el intervalo de confianza al 90% para la tasa de impuestos promedio en los países de África.

# %% [markdown]
# ### 3. Ejercicios prueba de hipótesis: Hasta ahora en la lección y en los ejercicios de la clase invertida os hemos propuesto un contexto y unas hipótesis para entender que es la prueba de hipótesis. Ahora es tu turno, tienes que pensar en 2 hipótesis que quieras aceptar o rechazar usando una prueba de hipótesis en base a los datos que tenemos.
